# %%
#%pip install azure-ai-projects azure-ai-agents azure-identity --pre
#%pip install python-dotenv

# %%
# ------------------------------------
# Copyright (c) Microsoft Corporation.
# Licensed under the MIT License.
# ------------------------------------

"""
DESCRIPTION:
    This sample demonstrates how to use agent operations with the
    Model Context Protocol (MCP) tool from the Azure Agents service using a synchronous client.
    To learn more about Model Context Protocol, visit https://modelcontextprotocol.io/

USAGE:
    python sample_agents_mcp.py

    Before running the sample:

    pip install azure-ai-projects azure-ai-agents azure-identity --pre

    Set these environment variables with your own values:
    1) PROJECT_ENDPOINT - The Azure AI Project endpoint, as found in the Overview
                          page of your Azure AI Foundry portal.
    2) MODEL_DEPLOYMENT_NAME - The deployment name of the AI model, as found under the "Name" column in
       the "Models + endpoints" tab in your Azure AI Foundry project.
    3) MCP_SERVER_URL - The URL of your MCP server endpoint.
    4) MCP_SERVER_LABEL - A label for your MCP server.
"""

import os, time
from azure.ai.projects import AIProjectClient
from azure.identity import DefaultAzureCredential
from azure.ai.agents.models import McpTool, RequiredMcpToolCall, SubmitToolApprovalAction, ToolApproval

from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
# Get MCP server configuration from environment variables
mcp_server_url = os.getenv("MCP_SERVER_URL", "https://gitmcp.io/Azure/azure-rest-api-specs")
mcp_server_label = os.getenv("MCP_SERVER_LABEL", "github")

# %%
project_client = AIProjectClient(
    endpoint=os.environ["PROJECT_ENDPOINT"],
    credential=DefaultAzureCredential(),
)

# %%
# [START create_agent_with_mcp_tool]
# Initialize agent MCP tool
mcp_tool = McpTool(
    server_label=mcp_server_label,
    server_url=mcp_server_url,
    allowed_tools=[],  # Optional: specify allowed tools
)

# %%
# You can also add or remove allowed tools dynamically
search_api_code = "search_azure_rest_api_code"
mcp_tool.allow_tool(search_api_code)
print(f"Allowed tools: {mcp_tool.allowed_tools}")
# Out:
# Allowed tools: ['search_azure_rest_api_code']

# %%
# Create agent with MCP tool and process agent run
with project_client:
    agents_client = project_client.agents

    # Create a new agent.
    # NOTE: To reuse existing agent, fetch it with get_agent(agent_id)
    agent = agents_client.create_agent(
        model=os.environ["MODEL_DEPLOYMENT_NAME"],
        name="my-mcp-agent",
        instructions="You are a helpful agent that can use MCP tools to assist users. Use the available MCP tools to answer questions and perform tasks.",
        tools=mcp_tool.definitions,
    )
    # [END create_agent_with_mcp_tool]

    print(f"Created agent, ID: {agent.id}")
    print(f"MCP Server: {mcp_tool.server_label} at {mcp_tool.server_url}")

    # Create thread for communication
    thread = agents_client.threads.create()
    print(f"Created thread, ID: {thread.id}")

    # Create message to thread
    message = agents_client.messages.create(
        thread_id=thread.id,
        role="user",
        content="Please summarize the Azure REST API specifications Readme",
    )
    print(f"Created message, ID: {message.id}")

    # [START handle_tool_approvals]
    # Create and process agent run in thread with MCP tools
    mcp_tool.update_headers("SuperSecret", "123456")
    # mcp_tool.set_approval_mode("never")  # Uncomment to disable approval requirement
    run = agents_client.runs.create(thread_id=thread.id, agent_id=agent.id, tool_resources=mcp_tool.resources)
    print(f"Created run, ID: {run.id}")

    while run.status in ["queued", "in_progress", "requires_action"]:
        time.sleep(1)
        run = agents_client.runs.get(thread_id=thread.id, run_id=run.id)

        if run.status == "requires_action" and isinstance(run.required_action, SubmitToolApprovalAction):
            tool_calls = run.required_action.submit_tool_approval.tool_calls
            if not tool_calls:
                print("No tool calls provided - cancelling run")
                agents_client.runs.cancel(thread_id=thread.id, run_id=run.id)
                break

            tool_approvals = []
            for tool_call in tool_calls:
                if isinstance(tool_call, RequiredMcpToolCall):
                    try:
                        print(f"Approving tool call: {tool_call}")
                        tool_approvals.append(
                            ToolApproval(
                                tool_call_id=tool_call.id,
                                approve=True,
                                headers=mcp_tool.headers,
                            )
                        )
                    except Exception as e:
                        print(f"Error approving tool_call {tool_call.id}: {e}")

            print(f"tool_approvals: {tool_approvals}")
            if tool_approvals:
                agents_client.runs.submit_tool_outputs(
                    thread_id=thread.id, run_id=run.id, tool_approvals=tool_approvals
                )

        print(f"Current run status: {run.status}")
        # [END handle_tool_approvals]

    print(f"Run completed with status: {run.status}")
    if run.status == "failed":
        print(f"Run failed: {run.last_error}")

    # Display run steps and tool calls
    run_steps = agents_client.run_steps.list(thread_id=thread.id, run_id=run.id)

    # Loop through each step
    for step in run_steps:
        print(f"Step {step['id']} status: {step['status']}")

        # Check if there are tool calls in the step details
        step_details = step.get("step_details", {})
        tool_calls = step_details.get("tool_calls", [])

        if tool_calls:
            print("  MCP Tool calls:")
            for call in tool_calls:
                print(f"    Tool Call ID: {call.get('id')}")
                print(f"    Type: {call.get('type')}")

        print()  # add an extra newline between steps

    # Fetch and log all messages
    messages = agents_client.messages.list(thread_id=thread.id)
    print("\nConversation:")
    print("-" * 50)
    for msg in messages:
        if msg.text_messages:
            last_text = msg.text_messages[-1]
            print(f"{msg.role.upper()}: {last_text.text.value}")
            print("-" * 50)

    # Example of dynamic tool management
    print(f"\nDemonstrating dynamic tool management:")
    print(f"Current allowed tools: {mcp_tool.allowed_tools}")

    # Remove a tool
    try:
        mcp_tool.disallow_tool(search_api_code)
        print(f"After removing {search_api_code}: {mcp_tool.allowed_tools}")
    except ValueError as e:
        print(f"Error removing tool: {e}")

    # Clean-up and delete the agent once the run is finished.
    # NOTE: Comment out this line if you plan to reuse the agent later.
    agents_client.delete_agent(agent.id)
    print("Deleted agent")
# Out:
# Created agent, ID: asst_cEc580kqI83EmS85RqzaOOh4
# MCP Server: github at https://gitmcp.io/Azure/azure-rest-api-specs
# Created thread, ID: thread_EounaMJUYiSs4YOGKATfRwvt
# Created message, ID: msg_UDbL9xzumyj6gln6qQOnDxXa
# Created run, ID: run_coJOcZxrj6SvlPOAdkn8Wa8v
# Current run status: RunStatus.IN_PROGRESS
# Current run status: RunStatus.IN_PROGRESS
# Current run status: RunStatus.IN_PROGRESS
# Current run status: RunStatus.IN_PROGRESS
# Current run status: RunStatus.IN_PROGRESS
# Current run status: RunStatus.IN_PROGRESS
# Current run status: RunStatus.IN_PROGRESS
# Current run status: RunStatus.IN_PROGRESS
# Current run status: RunStatus.IN_PROGRESS
# Approving tool call: {'id': 'call_FSlcyPbRLv81O5J4VstMh0fe', 'type': 'mcp', 'arguments': '{"query":"Readme","page":1}', 'name': 'search_azure_rest_api_code', 'server_label': 'github'}
# tool_approvals: [{'tool_call_id': 'call_FSlcyPbRLv81O5J4VstMh0fe', 'approve': True, 'headers': {'SuperSecret': '123456'}}]
# Current run status: RunStatus.REQUIRES_ACTION
# Current run status: RunStatus.IN_PROGRESS
# Current run status: RunStatus.IN_PROGRESS
# Current run status: RunStatus.IN_PROGRESS
# Current run status: RunStatus.IN_PROGRESS
# Current run status: RunStatus.IN_PROGRESS
# Current run status: RunStatus.IN_PROGRESS
# Current run status: RunStatus.IN_PROGRESS
# Current run status: RunStatus.IN_PROGRESS
# Current run status: RunStatus.IN_PROGRESS
# Current run status: RunStatus.IN_PROGRESS
# Current run status: RunStatus.IN_PROGRESS
# Current run status: RunStatus.IN_PROGRESS
# Current run status: RunStatus.IN_PROGRESS
# Current run status: RunStatus.IN_PROGRESS
# Current run status: RunStatus.IN_PROGRESS
# Current run status: RunStatus.IN_PROGRESS
# Current run status: RunStatus.IN_PROGRESS
# Current run status: RunStatus.IN_PROGRESS
# Current run status: RunStatus.IN_PROGRESS
# Current run status: RunStatus.COMPLETED
# Run completed with status: RunStatus.COMPLETED
# Step step_jRAKBx70WqnVVPCG8AuOkFqm status: completed
#
# Step step_JobZtLdo4JV0SyQakbzYAl9R status: completed
#   MCP Tool calls:
#     Tool Call ID: call_m1HD6sH1IHmDyG1A3ogCjOqY
#     Type: mcp
#
# Step step_9oYvrYU8RHu4zhgI3BHkbirm status: completed
#   MCP Tool calls:
#     Tool Call ID: call_UyxerycTyCob5niE20PhVzXD
#     Type: mcp
#
# Step step_BOtWcciNtvH69Vo9QaURHxH9 status: completed
#   MCP Tool calls:
#     Tool Call ID: call_SFEpilLvh8tLB9rlftljUOGC
#     Type: mcp
#
# Step step_tByp84s8SIBZb9CDwkkB2una status: completed
#   MCP Tool calls:
#     Tool Call ID: call_FSlcyPbRLv81O5J4VstMh0fe
#     Type: mcp
#
#
# Conversation:
# --------------------------------------------------
# ASSISTANT: The Azure REST API Specs repository (`azure-rest-api-specs`) contains a very large number of `README.md` and `readme.md` files across its many subfolders, reflecting the wide set of services and tools it covers.
#
# ## General Summary (Based on Structure and Standard Readme Practices)
#
# **Azure REST API Specs Readme files** provide:
# - **Overview of each service or feature**: Every Azure service or API specification directory (like Cognitive Services, Batch, Kubernetes, etc.) typically includes its own `readme.md`, explaining the scope, intended audience, and sometimes key scenarios.
# - **Auto-generation Guidance**: Many readmes document how SDKs can be generated from the spec using various tools (e.g., AutoRest, TypeSpec), including language settings, example commands, and configuration.
# - **File and Directory Structure**: Guidance on how API specs, examples, and configuration files are organized.
# - **Contribution & Review Process**: Information about how to contribute to or validate API specs, plus links to review, CI/CD pipelines, and testing scripts.
# - **Versioning & Change Management**: Explanation of versioning strategy for APIs (preview, beta, stable), and sometimes details about breaking changes.
# - **References to Core Documentation**: Many readmes link out to central docs such as the [Directory structure guide](https://github.com/Azure/azure-rest-api-specs/blob/main/documentation/directory-structure.md) or [REST API Dev Process](https://github.com/Azure/azure-rest-api-specs/blob/main/documentation/typespec-rest-api-dev-process.md).
#
# ## Repository-wide Guidance
#
# While each service may have its own tailored `readme.md`, the overall approach is:
# - To describe **how the OpenAPI/Swagger specifications for each Azure service are structured, maintained, and used** for client library generation and REST documentation.
# - To ensure **consistent, high-quality API definitions** that can be consumed by SDK automation, code generators, and documentation tools.
# - To foster **collaboration and contribution** from the open-source and Azure engineering communities.
#
# ## To Read a Specific Readme
#
# If you want the summary or content of a particular `readme.md` for a given Azure service (e.g., Key Vault, CosmosDB, Kubernetes), please specify the path or the service, and I can provide a focused summary or the content of that file.
#
# For a top-level, repository-wide overview, refer to [this directory-structure guide](https://github.com/Azure/azure-rest-api-specs/blob/main/documentation/directory-structure.md) and [the onboarding/contribution documentation](https://github.com/Azure/azure-rest-api-specs/tree/main/documentation).
#
# **Let me know if you'd like a summary or content for a specific subfolder or service!**
# --------------------------------------------------
# USER: Please summarize the Azure REST API specifications Readme
# --------------------------------------------------
#
# Demonstrating dynamic tool management:
# Current allowed tools: ['search_azure_rest_api_code']
# After removing search_azure_rest_api_code: []
# Deleted agent
