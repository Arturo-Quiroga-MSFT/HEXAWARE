# %%
#%pip install python-dotenv azure-identity
#%pip install --pre azure-ai-projects
#%pip install aiohttp

# %%
# ------------------------------------
# Copyright (c) Microsoft Corporation.
# Licensed under the MIT License.
# ------------------------------------

"""
DESCRIPTION:
    This sample demonstrates how to use Agent operations with the Deep Research tool from
    the Azure Agents service through the **asynchronous** Python client. Deep Research issues
    external Bing Search queries and invokes an LLM, so each run can take several minutes
    to complete.

    For more information see the Deep Research Tool document: https://aka.ms/agents-deep-research

USAGE:
    python sample_agents_deep_research_async.py

    Before running the sample:

    pip install azure-ai-projects azure-ai-agents azure-identity aiohttp

    Set these environment variables with your own values:
    1) PROJECT_ENDPOINT - The Azure AI Project endpoint, as found in the Overview
                          page of your Azure AI Foundry portal.
    2) MODEL_DEPLOYMENT_NAME - The deployment name of the arbitration AI model, as found under the "Name" column in
       the "Models + endpoints" tab in your Azure AI Foundry project.
    3) DEEP_RESEARCH_MODEL_DEPLOYMENT_NAME - The deployment name of the Deep Research AI model, as found under the "Name" column in
       the "Models + endpoints" tab in your Azure AI Foundry project.
    4) AZURE_BING_CONNECTION_ID - The ID of the Bing connection, in the format of:
       /subscriptions/{subscription-id}/resourceGroups/{resource-group-name}/providers/Microsoft.MachineLearningServices/workspaces/{workspace-name}/connections/{connection-name}
"""

import asyncio
import os
from typing import Optional

from azure.ai.projects.aio import AIProjectClient
from azure.ai.agents.aio import AgentsClient
from azure.ai.agents.models import DeepResearchTool, MessageRole, ThreadMessage
from azure.identity.aio import DefaultAzureCredential

# Load environment variables from .env file
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
async def fetch_and_print_new_agent_response(
    thread_id: str,
    agents_client: AgentsClient,
    last_message_id: Optional[str] = None,
) -> Optional[str]:
    response = await agents_client.messages.get_last_message_by_role(
        thread_id=thread_id,
        role=MessageRole.AGENT,
    )

    if not response or response.id == last_message_id:
        return last_message_id

    print("\nAgent response:")
    print("\n".join(t.text.value for t in response.text_messages))

    # Print citation annotations (if any)
    for ann in response.url_citation_annotations:
        print(f"URL Citation: [{ann.url_citation.title}]({ann.url_citation.url})")

    return response.id

# %%
def create_research_summary(
        message : ThreadMessage,
        filepath: str = "research_summary.md"
) -> None:
    if not message:
        print("No message content provided, cannot create research summary.")
        return

    with open(filepath, "w", encoding="utf-8") as fp:
        # Write text summary
        text_summary = "\n\n".join([t.text.value.strip() for t in message.text_messages])
        fp.write(text_summary)

        # Write unique URL citations, if present
        if message.url_citation_annotations:
            fp.write("\n\n## References\n")
            seen_urls = set()
            for ann in message.url_citation_annotations:
                url = ann.url_citation.url
                title = ann.url_citation.title or url
                if url not in seen_urls:
                    fp.write(f"- [{title}]({url})\n")
                    seen_urls.add(url)

    print(f"Research summary written to '{filepath}'.")

# %%
import nest_asyncio
import asyncio

# %%
async def main() -> None:

    project_client = AIProjectClient(
        endpoint=os.environ["PROJECT_ENDPOINT"],
        credential=DefaultAzureCredential(),
    )

    # Initialize a Deep Research tool with Bing Connection ID and Deep Research model deployment name
    deep_research_tool = DeepResearchTool(
        bing_grounding_connection_id=os.environ["AZURE_BING_CONNECTION_ID"],
        deep_research_model=os.environ["DEEP_RESEARCH_MODEL_DEPLOYMENT_NAME"],
    )

    async with project_client:

        agents_client = project_client.agents

        # Create a new agent that has the Deep Research tool attached.
        # NOTE: To add Deep Research to an existing agent, fetch it with `get_agent(agent_id)` and then,
        # update the agent with the Deep Research tool.
        agent = await agents_client.create_agent(
            model=os.environ["MODEL_DEPLOYMENT_NAME"],
            name="my-agent",
            instructions="You are a helpful Agent that assists in researching scientific topics.",
            tools=deep_research_tool.definitions,
        )
        print(f"Created agent, ID: {agent.id}")

        # Create thread for communication
        thread = await agents_client.threads.create()
        print(f"Created thread, ID: {thread.id}")

        # Create message to thread
        message = await agents_client.messages.create(
            thread_id=thread.id,
            role="user",
            content=(
                "Research the current state of studies on orca intelligence and orca language, including what is currently known about orcas' cognitive capabilities and communication systems. Do not ask questions or seek clarifications, just provide a comprehensive overview based on the latest research findings."
            ),
        )
        print(f"Created message, ID: {message.id}")

        print("Start processing the message... this may take a few minutes to finish. Be patient!")
        # Poll the run as long as run status is queued or in progress
        run = await agents_client.runs.create(thread_id=thread.id, agent_id=agent.id)
        last_message_id: Optional[str] = None
        while run.status in ("queued", "in_progress"):
            await asyncio.sleep(1)
            run = await agents_client.runs.get(thread_id=thread.id, run_id=run.id)

            last_message_id = await fetch_and_print_new_agent_response(
                thread_id=thread.id,
                agents_client=agents_client,
                last_message_id=last_message_id,
            )
            print(f"Run status: {run.status}")

        print(f"Run finished with status: {run.status}, ID: {run.id}")

        if run.status == "failed":
            print(f"Run failed: {run.last_error}")

        # Fetch the final message from the agent in the thread and create a research summary
        final_message = await agents_client.messages.get_last_message_by_role(
            thread_id=thread.id, role=MessageRole.AGENT
        )
        if final_message:
            create_research_summary(final_message)

        # Clean-up and delete the agent once the run is finished.
        # NOTE: Comment out this line if you plan to reuse the agent later.
        await agents_client.delete_agent(agent.id)
        print("Deleted agent")


nest_asyncio.apply()
await main()
# Out:
# Created agent, ID: asst_1DNx405GYFJlIUnC9ORzlSKh
# Created thread, ID: thread_UAkQI79mvphv3rJmD7COtt0S
# Created message, ID: msg_4CY3JX83Leocgmw87ICR6SQg
# Start processing the message... this may take a few minutes to finish. Be patient!
# Run status: RunStatus.IN_PROGRESS
#
# Agent response:
# Sure, I will prepare a comprehensive overview of the latest research regarding orca intelligence and orca language, summarizing current scientific understanding of their cognitive abilities and communication systems. I will include up-to-date findings, key studies, and recent advances in the field.
#
# Title: Overview of Orca Intelligence and Language Research
#
#  Starting deep research...
#
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
#
# Agent response:
# cot_summary: **Gathering new data**
#
# I’m focusing on recent scientific findings about orca intelligence and communication, examining their cognitive abilities, social learning, and complex vocalizations since 2020. Progress includes understanding dialects and potential non-human "language" aspects.
#
# **Mapping out orca intelligence**
#
# Gathering references on orca cognitive abilities, including problem-solving and imitation, by examining their complex social structures and extensive brain folds, likely paralleling dolphins. 【1†Bing Search】
#
# URL Citation: [Bing Search: 'orca intelligence communication studies 2021 2022'](https://www.bing.com/search?q=orca%20intelligence%20communication%20studies%202021%202022)
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
#
# Agent response:
# cot_summary: **Evaluating sources**
#
# I’m gathering info on sources like ResearchGate, Orca Behavior Institute, and American Oceans, considering their credibility and whether they offer comprehensive details on orca studies.
#
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
#
# Agent response:
# cot_summary: **Examining orca calls**
#
# Tracking orca calls with AI from Canada's coast at Friedrich Alexander University. Hopes to identify dialects and understand cultural transmission.
#
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
#
# Agent response:
# cot_summary: **Pulling together studies**
#
# Exploring orca communication complexity and potentials underlying a sophisticated social language system. Progressing towards identifying unique ultrasonic signals for identification. 【1†Bing Search】
#
# URL Citation: [Bing Search: 'Christian Bergler orca calls paper 2022'](https://www.bing.com/search?q=Christian%20Bergler%20orca%20calls%20paper%202022)
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
#
# Agent response:
# cot_summary: **Separation techniques**
#
# I'm gathering insights on "ORCA-WHISPER" and "ORCA-PARTY," deep learning tools for separating and generating orca calls. 【1†Bing Search】
#
# URL Citation: [Bing Search: 'orca problem solving study 2021'](https://www.bing.com/search?q=orca%20problem%20solving%20study%202021)
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
#
# Agent response:
# cot_summary: **Mapping orca innovation**
#
# OK, now I'm brainstorming different ways to approach the problem using "innovation in orcas" to find relevant studies or news articles.
#
# Run status: RunStatus.IN_PROGRESS
#
# Agent response:
# cot_summary: **Checking visibility**
#
# I'm piecing together if the PDF shows only the first lines or something more.
#
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
#
# Agent response:
# cot_summary: **Navigating text extraction**
# The current environment seems unable to parse PDFs directly. Instead, I can try clicking on a different area or searching for a specific text snippet to locate a text copy. 【1†Bing Search】
#
# URL Citation: [Bing Search: '"Manitzas Hill 2022 Killer whale creativity"'](https://www.bing.com/search?q=%22Manitzas%20Hill%202022%20Killer%20whale%20creativity%22)
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
#
# Agent response:
# cot_summary: **Investigating known figures**
# I'm digging into "Killer whales creativity 2022 Hill" to understand key influencers. 【1†Bing Search】
#
# URL Citation: [Bing Search: '"complex cognitive abilities ... flexible thinking or creativity" orca'](https://www.bing.com/search?q=%22complex%20cognitive%20abilities%20...%20flexible%20thinking%20or%20creativity%22%20orca)
# Run status: RunStatus.IN_PROGRESS
#
# Agent response:
# cot_summary:  【1†Bing Search】
#
# URL Citation: [Bing Search: 'Manitzas Hill orca creativity 2022 training'](https://www.bing.com/search?q=Manitzas%20Hill%20orca%20creativity%202022%20training)
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
#
# Agent response:
# cot_summary: **Pulling together**
#
# I'm starting to see that entry number 4 is mentioning a Chinese article on killer whale innovation and teaching creativity, likely from Animal Cognition, dated September 20, 2022.
#
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
#
# Agent response:
# cot_summary: **Examining findings**
#
# The article highlights the cognitive flexibility and creativity of 9 captive killer whales, with younger whales displaying more novelty in their behaviors. It also notes their tool use, such as luring seagulls with fish.
#
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
#
# Agent response:
# cot_summary: **Investigating orca intelligence**
#
# Examining orca cognitive skills and social behaviors, including innovative luring tactics and cooperative wave-washing, while noting cultural transmission and recent boat attack phenomena. 【1†Bing Search】
#
# URL Citation: [Bing Search: 'orcas attacking boats learned behavior recent study 2023'](https://www.bing.com/search?q=orcas%20attacking%20boats%20learned%20behavior%20recent%20study%202023)
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
#
# Agent response:
# cot_summary: This claim, from Live Science, suggests that a traumatized orca sparked a behavior, which then spread through social interaction.
#
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
#
# Agent response:
# cot_summary: **Tracking orca behavior**
#
# Monitoring orca-boat interactions since 2020, involving rudder targeting and surprising interests. This behaviour, possibly rooted in initial trauma, is being extensively studied. 【1†Bing Search】
#
# URL Citation: [Bing Search: 'Marine Mammal Science June 2022 orca boats Lopez Fernandez'](https://www.bing.com/search?q=Marine%20Mammal%20Science%20June%202022%20orca%20boats%20Lopez%20Fernandez)
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
#
# Agent response:
# cot_summary: **Referencing sources**
#
# I'm mapping out the use of Live Science references and considering citing primary literature, including a June 2022 study on orcas attacking boat rudders. 【1†Bing Search】
#
# URL Citation: [Bing Search: '2018 orca mimic human speech study Wikie'](https://www.bing.com/search?q=2018%20orca%20mimic%20human%20speech%20study%20Wikie)
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
#
# Agent response:
# cot_summary: **Investigating primary sources**
#
# It's interesting to see that a 2018 study by Abramson et al., possibly published in Proc. R. Soc B, is being referenced. Other potential sources include Forbes and Phys.org.
#
# Run status: RunStatus.IN_PROGRESS
#
# Agent response:
# cot_summary: **Locating the source**
#
# I’m pinpointing the origin, possibly a snippet or PDF.
#
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
#
# Agent response:
# cot_summary: **Evaluating access options**
#
# I'm thinking through the limited access to Phys.org, considering the challenges of dealing with PDF formats for a clearer solution.
#
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
#
# Agent response:
# cot_summary: **Investigating vocal learning**
#
# Checking policies on killer whales as open-ended vocal learners, capable of cross-species vocal imitation, and exploring the "grandmother effect" in their social structure. 【1†Bing Search】
#
# URL Citation: [Bing Search: 'killer whale mirror self-recognition study'](https://www.bing.com/search?q=killer%20whale%20mirror%20self-recognition%20study)
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
#
# Agent response:
# cot_summary: **Gathering insights**
#
# I’m pulling together studies on killer whales' cognitive abilities, including mirror exposure and mark tests, dating back to 2008 or earlier, and likely involving Delfour & Marten or similar mid-2000s research.
#
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
#
# Agent response:
# cot_summary: **Revisiting results**
#
# OK, let me see. The search yielded articles on Apoptotic bodies, which aren't related. I should refine the search terms.
#
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
#
# Agent response:
# cot_summary: **Considering self-awareness**
#
# I’m gathering info on the Delfour & Marten 2001 study, which suggests that killer and false killer whales show cognitive signs of self-recognition, indicating self-awareness. 【1†Bing Search】
#
# URL Citation: [Bing Search: 'killer whale long-term memory'](https://www.bing.com/search?q=killer%20whale%20long-term%20memory)
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
#
# Agent response:
# cot_summary: **Exploring key findings**
#
# I’m digging into the Stranger article, likely featuring neuroscientist Lori Marino, and uncovering how orcas' developed brain regions are linked to emotional learning and memory, suggesting a rich emotional capacity.
#
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
#
# Agent response:
# cot_summary: **Mapping brain complexity**
#
# Orcas boast the most gyrified brain on Earth with a 5.7 index, surpassing humans' 2.2. Their paralimbic regions for emotional learning and self-awareness are exceptionally developed.
#
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
#
# Agent response:
# cot_summary: **Understanding orcas**
#
# I'm mapping out orcas' advanced cognition through their large, folded brains and high encephalization quotient, comparing them to sperm whales, dolphins, and humans. 【1†Bing Search】
#
# URL Citation: [Bing Search: 'orca culture social learning whales 2021'](https://www.bing.com/search?q=orca%20culture%20social%20learning%20whales%202021)
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
#
# Agent response:
# cot_summary: **Mapping orca interactions**
#
# I'm thinking about the complex social relationships among orcas, especially their stable friendships and communication, based on insights from NewScientist.
#
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
#
# Agent response:
# cot_summary: **Analyzing orca social bonds**
#
# I’m mapping out how orcas form close, same-sex friendships within pods, use frequent physical contact for bonding, and have distinct pod cultures and group calls. It’s fascinating to see these intricate social ties. 【1†Bing Search】
#
# URL Citation: [Bing Search: 'do orcas have language study 2020'](https://www.bing.com/search?q=do%20orcas%20have%20language%20study%202020)
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
#
# Agent response:
# cot_summary: **Assessing sources**
#
# I’m gathering info on arXiv, Wild Orca, and news.stonybrook.edu, looking at semantic language in Orcas and their complex communication patterns.
#
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
#
# Agent response:
# cot_summary: **Investigating orca calls**
#
# I'm exploring a study that achieved 96.4% accuracy in predicting orca behaviors from their calls, suggesting these vocalizations might encode specific semantic information about their activities.
#
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
#
# Agent response:
# cot_summary: **Comparing whale communication**
#
# I’m exploring the implications of a 2025 Science Advances paper that underscores the efficiency of whale communication similar to human language compression. Fascinating patterns in 16 species reveal complexities and environmental influences.
#
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
#
# Agent response:
# cot_summary: **Organizing the report**
#
# Mapping out sections: introduction, cognitive abilities, communication, recent developments, and a final wrap-up. Each section will be thoroughly explained, using citations and examples. 【1†Bing Search】
#
# URL Citation: [Bing Search: 'orca call spectrogram image'](https://www.bing.com/search?q=orca%20call%20spectrogram%20image)
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
#
# Agent response:
# cot_summary: **Weighing options**
#
# I’m thinking through an image of orcas hunting for its "intelligent" behavior, possibly from Unsplash or Flickr, considering the risk of embedding images.
#
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
#
# Agent response:
# cot_summary: **Confirming image details**
#
# Checking if Earth Island Journal's image comes from Unsplash. Searching "Frank Busch orca unsplash" for verification. 【1†Bing Search】
#
# URL Citation: [Bing Search: '"Frank Busch" orca unsplash photo'](https://www.bing.com/search?q=%22Frank%20Busch%22%20orca%20unsplash%20photo)
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
#
# Agent response:
# cot_summary:
#
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
#
# Agent response:
# cot_summary: **Evaluating image sources**
#
# I'm weighing the merits of using Unsplash or Pexels for searching orca images. Option 3, featuring an image from Andre Estevez via Pexels, intrigues me.
#
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
#
# Agent response:
# cot_summary: **Analyzing article components**
# I’m breaking down an article's details, including checked policies and image sources like Openverse and Unsplash, ensuring compliance with guidelines.
#
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
#
# Agent response:
# cot_summary: **Investigating image sources
#
# I'm digging into HTML tags and background settings to trace Unsplash images. Their separate loading or tag inclusion might be possibilities.
#
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
#
# Agent response:
# cot_summary: **Laying out orca communication**
#
# I'm breaking down orca communication into sections like vocal repertoire, complexity, and semantic debates. The focus is on their calls, dialects, and the challenge of full interpretation.
#
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
#
# Agent response:
# cot_summary: **Showcasing orca traits**
# The article highlights orca vocal mimicry, cultural traits, and intelligence, including their salmon head fads and brain size.
#
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
#
# Agent response:
# cot_summary: **Examining orca cognition**
#
# Lori Marino highlights orca brain structure, imparts their communication styles, and shares insights on their problem solving and social learning.
#
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
#
# Agent response:
# cot_summary: **Revering ancient trends**
#
# Orcas are now adopting the ancient practice of wearing dead salmon hats, a trend they've abandoned for 37 years. 【1†Bing Search】
#
# URL Citation: [Bing Search: 'LiveScience salmon hats orcas 37 years'](https://www.bing.com/search?q=LiveScience%20salmon%20hats%20orcas%2037%20years)
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
#
# Agent response:
# cot_summary: **Assembling the content**
#
# I'll include orca's brain structure, problem-solving, social learning, and memory, incorporating old research and notable cultural details. 【1†Bing Search】
#
# URL Citation: [Bing Search: 'older female orca knowledge survival study'](https://www.bing.com/search?q=older%20female%20orca%20knowledge%20survival%20study)
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
#
# Agent response:
# cot_summary: **Refining the search**
#
# I’m clarifying the specifics of the "grandmother effect" study, likely in "Current Biology" or "PNAS" from 2019 or 2020.
#
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
# Run status: RunStatus.IN_PROGRESS
# ---------------------------------------------------------------------------
# CancelledError                            Traceback (most recent call last)
# Cell In[6], line 77
#      73         print("Deleted agent")
#      76 nest_asyncio.apply()
# ---> 77 await main()
#
# Cell In[6], line 51, in main()
#      48     await asyncio.sleep(1)
#      49     run = await agents_client.runs.get(thread_id=thread.id, run_id=run.id)
# ---> 51     last_message_id = await fetch_and_print_new_agent_response(
#      52         thread_id=thread.id,
#      53         agents_client=agents_client,
#      54         last_message_id=last_message_id,
#      55     )
#      56     print(f"Run status: {run.status}")
#      58 print(f"Run finished with status: {run.status}, ID: {run.id}")
#
# Cell In[3], line 6, in fetch_and_print_new_agent_response(thread_id, agents_client, last_message_id)
#       1 async def fetch_and_print_new_agent_response(
#       2     thread_id: str,
#       3     agents_client: AgentsClient,
#       4     last_message_id: Optional[str] = None,
#       5 ) -> Optional[str]:
# ----> 6     response = await agents_client.messages.get_last_message_by_role(
#       7         thread_id=thread_id,
#       8         role=MessageRole.AGENT,
#       9     )
#      11     if not response or response.id == last_message_id:
#      12         return last_message_id
#
# File ~/GITHUB/AZURE AI AGENT SERVICE/.venv7/lib/python3.12/site-packages/azure/ai/agents/aio/operations/_patch.py:2238, in MessagesOperations.get_last_message_by_role(self, thread_id, role, **kwargs)
#    2222 """
#    2223 Return the most-recent message in *thread_id* authored by *role*.
#    2224
#    (...)   2234 :rtype: Optional[~azure.ai.agents.models.ThreadMessage]
#    2235 """
#    2236 pageable = self.list(thread_id, **kwargs)
# -> 2238 async for message in pageable:
#    2239     if message.role == role:
#    2240         return message
#
# File ~/GITHUB/AZURE AI AGENT SERVICE/.venv7/lib/python3.12/site-packages/azure/core/async_paging.py:142, in AsyncItemPaged.__anext__(self)
#     140 if self._page_iterator is None:
#     141     self._page_iterator = self.by_page()
# --> 142     return await self.__anext__()
#     143 if self._page is None:
#     144     # Let it raise StopAsyncIteration
#     145     self._page = await self._page_iterator.__anext__()
#
# File ~/GITHUB/AZURE AI AGENT SERVICE/.venv7/lib/python3.12/site-packages/azure/core/async_paging.py:145, in AsyncItemPaged.__anext__(self)
#     142     return await self.__anext__()
#     143 if self._page is None:
#     144     # Let it raise StopAsyncIteration
# --> 145     self._page = await self._page_iterator.__anext__()
#     146     return await self.__anext__()
#     147 try:
#
# File ~/GITHUB/AZURE AI AGENT SERVICE/.venv7/lib/python3.12/site-packages/azure/core/async_paging.py:94, in AsyncPageIterator.__anext__(self)
#      92     raise StopAsyncIteration("End of paging")
#      93 try:
# ---> 94     self._response = await self._get_next(self.continuation_token)
#      95 except AzureError as error:
#      96     if not error.continuation_token:
#
# File ~/GITHUB/AZURE AI AGENT SERVICE/.venv7/lib/python3.12/site-packages/azure/ai/agents/aio/operations/_operations.py:916, in MessagesOperations.list.<locals>.get_next(_continuation_token)
#     913 _request = prepare_request(_continuation_token)
#     915 _stream = False
# --> 916 pipeline_response: PipelineResponse = await self._client._pipeline.run(  # pylint: disable=protected-access
#     917     _request, stream=_stream, **kwargs
#     918 )
#     919 response = pipeline_response.http_response
#     921 if response.status_code not in [200]:
#
# File ~/GITHUB/AZURE AI AGENT SERVICE/.venv7/lib/python3.12/site-packages/azure/core/pipeline/_base_async.py:229, in AsyncPipeline.run(self, request, **kwargs)
#     227 pipeline_request = PipelineRequest(request, context)
#     228 first_node = self._impl_policies[0] if self._impl_policies else _AsyncTransportRunner(self._transport)
# --> 229 return await first_node.send(pipeline_request)
#
# File ~/GITHUB/AZURE AI AGENT SERVICE/.venv7/lib/python3.12/site-packages/azure/core/pipeline/_base_async.py:77, in _SansIOAsyncHTTPPolicyRunner.send(self, request)
#      75 response: PipelineResponse[HTTPRequestType, AsyncHTTPResponseType]
#      76 try:
# ---> 77     response = await self.next.send(request)
#      78 except Exception:
#      79     await _await_result(self._policy.on_exception, request)
#
# File ~/GITHUB/AZURE AI AGENT SERVICE/.venv7/lib/python3.12/site-packages/azure/core/pipeline/_base_async.py:77, in _SansIOAsyncHTTPPolicyRunner.send(self, request)
#      75 response: PipelineResponse[HTTPRequestType, AsyncHTTPResponseType]
#      76 try:
# ---> 77     response = await self.next.send(request)
#      78 except Exception:
#      79     await _await_result(self._policy.on_exception, request)
#
#     [... skipping similar frames: _SansIOAsyncHTTPPolicyRunner.send at line 77 (2 times)]
#
# File ~/GITHUB/AZURE AI AGENT SERVICE/.venv7/lib/python3.12/site-packages/azure/core/pipeline/_base_async.py:77, in _SansIOAsyncHTTPPolicyRunner.send(self, request)
#      75 response: PipelineResponse[HTTPRequestType, AsyncHTTPResponseType]
#      76 try:
# ---> 77     response = await self.next.send(request)
#      78 except Exception:
#      79     await _await_result(self._policy.on_exception, request)
#
# File ~/GITHUB/AZURE AI AGENT SERVICE/.venv7/lib/python3.12/site-packages/azure/core/pipeline/policies/_redirect_async.py:76, in AsyncRedirectPolicy.send(self, request)
#      74 original_domain = get_domain(request.http_request.url) if redirect_settings["allow"] else None
#      75 while redirects_remaining:
# ---> 76     response = await self.next.send(request)
#      77     redirect_location = self.get_redirect_location(response)
#      78     if redirect_location and redirect_settings["allow"]:
#
# File ~/GITHUB/AZURE AI AGENT SERVICE/.venv7/lib/python3.12/site-packages/azure/core/pipeline/policies/_retry_async.py:178, in AsyncRetryPolicy.send(self, request)
#     176 self._configure_timeout(request, absolute_timeout, is_response_error)
#     177 request.context["retry_count"] = len(retry_settings["history"])
# --> 178 response = await self.next.send(request)
#     179 if self.is_retry(retry_settings, response):
#     180     retry_active = self.increment(retry_settings, response=response)
#
# File ~/GITHUB/AZURE AI AGENT SERVICE/.venv7/lib/python3.12/site-packages/azure/core/pipeline/policies/_authentication_async.py:104, in AsyncBearerTokenCredentialPolicy.send(self, request)
#     102 response: PipelineResponse[HTTPRequestType, AsyncHTTPResponseType]
#     103 try:
# --> 104     response = await self.next.send(request)
#     105 except Exception:
#     106     await await_result(self.on_exception, request)
#
# File ~/GITHUB/AZURE AI AGENT SERVICE/.venv7/lib/python3.12/site-packages/azure/core/pipeline/_base_async.py:77, in _SansIOAsyncHTTPPolicyRunner.send(self, request)
#      75 response: PipelineResponse[HTTPRequestType, AsyncHTTPResponseType]
#      76 try:
# ---> 77     response = await self.next.send(request)
#      78 except Exception:
#      79     await _await_result(self._policy.on_exception, request)
#
# File ~/GITHUB/AZURE AI AGENT SERVICE/.venv7/lib/python3.12/site-packages/azure/core/pipeline/_base_async.py:77, in _SansIOAsyncHTTPPolicyRunner.send(self, request)
#      75 response: PipelineResponse[HTTPRequestType, AsyncHTTPResponseType]
#      76 try:
# ---> 77     response = await self.next.send(request)
#      78 except Exception:
#      79     await _await_result(self._policy.on_exception, request)
#
#     [... skipping similar frames: _SansIOAsyncHTTPPolicyRunner.send at line 77 (2 times)]
#
# File ~/GITHUB/AZURE AI AGENT SERVICE/.venv7/lib/python3.12/site-packages/azure/core/pipeline/_base_async.py:77, in _SansIOAsyncHTTPPolicyRunner.send(self, request)
#      75 response: PipelineResponse[HTTPRequestType, AsyncHTTPResponseType]
#      76 try:
# ---> 77     response = await self.next.send(request)
#      78 except Exception:
#      79     await _await_result(self._policy.on_exception, request)
#
# File ~/GITHUB/AZURE AI AGENT SERVICE/.venv7/lib/python3.12/site-packages/azure/core/pipeline/_base_async.py:111, in _AsyncTransportRunner.send(self, request)
#     101 """Async HTTP transport send method.
#     102
#     103 :param request: The PipelineRequest object.
#    (...)    106 :rtype: ~azure.core.pipeline.PipelineResponse
#     107 """
#     108 cleanup_kwargs_for_transport(request.context.options)
#     109 return PipelineResponse(
#     110     request.http_request,
# --> 111     await self._sender.send(request.http_request, **request.context.options),
#     112     request.context,
#     113 )
#
# File ~/GITHUB/AZURE AI AGENT SERVICE/.venv7/lib/python3.12/site-packages/azure/core/pipeline/transport/_aiohttp.py:317, in AioHttpTransport.send(self, request, stream, proxies, **config)
#     315 read_timeout = config.pop("read_timeout", self.connection_config.read_timeout)
#     316 socket_timeout = aiohttp.ClientTimeout(sock_connect=timeout, sock_read=read_timeout)
# --> 317 result = await self.session.request(  # type: ignore
#     318     request.method,
#     319     request.url,
#     320     headers=request.headers,
#     321     data=self._get_request_data(request),
#     322     timeout=socket_timeout,
#     323     allow_redirects=False,
#     324     proxy=proxy,
#     325     **config,
#     326 )
#     327 if _is_rest(request):
#     328     from azure.core.rest._aiohttp import RestAioHttpTransportResponse
#
# File ~/GITHUB/AZURE AI AGENT SERVICE/.venv7/lib/python3.12/site-packages/aiohttp/client.py:770, in ClientSession._request(self, method, str_or_url, params, data, json, cookies, headers, skip_auto_headers, auth, allow_redirects, max_redirects, compress, chunked, expect100, raise_for_status, read_until_eof, proxy, proxy_auth, timeout, verify_ssl, fingerprint, ssl_context, ssl, server_hostname, proxy_headers, trace_request_ctx, read_bufsize, auto_decompress, max_line_size, max_field_size, middlewares)
#     767     handler = _connect_and_send_request
#     769 try:
# --> 770     resp = await handler(req)
#     771 # Client connector errors should not be retried
#     772 except (
#     773     ConnectionTimeoutError,
#     774     ClientConnectorError,
#     775     ClientConnectorCertificateError,
#     776     ClientConnectorSSLError,
#     777 ):
#
# File ~/GITHUB/AZURE AI AGENT SERVICE/.venv7/lib/python3.12/site-packages/aiohttp/client.py:748, in ClientSession._request.<locals>._connect_and_send_request(req)
#     746 resp = await req.send(conn)
#     747 try:
# --> 748     await resp.start(conn)
#     749 except BaseException:
#     750     resp.close()
#
# File ~/GITHUB/AZURE AI AGENT SERVICE/.venv7/lib/python3.12/site-packages/aiohttp/client_reqrep.py:532, in ClientResponse.start(self, connection)
#     530 try:
#     531     protocol = self._protocol
# --> 532     message, payload = await protocol.read()  # type: ignore[union-attr]
#     533 except http.HttpProcessingError as exc:
#     534     raise ClientResponseError(
#     535         self.request_info,
#     536         self.history,
#    (...)    539         headers=exc.headers,
#     540     ) from exc
#
# File ~/GITHUB/AZURE AI AGENT SERVICE/.venv7/lib/python3.12/site-packages/aiohttp/streams.py:672, in DataQueue.read(self)
#     670 self._waiter = self._loop.create_future()
#     671 try:
# --> 672     await self._waiter
#     673 except (asyncio.CancelledError, asyncio.TimeoutError):
#     674     self._waiter = None
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/asyncio/futures.py:289, in Future.__await__(self)
#     287 if not self.done():
#     288     self._asyncio_future_blocking = True
# --> 289     yield self  # This tells Task to wait for completion.
#     290 if not self.done():
#     291     raise RuntimeError("await wasn't used with future")
#
# CancelledError:
